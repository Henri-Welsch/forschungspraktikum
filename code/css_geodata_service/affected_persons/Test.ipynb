# %%
import pandas as pd
import geopandas as gpd

# %%
"""
 TODO: do
 - load population data csv file
 - load buildings
 - load polygon shape to get affected area
 - filter affected buildings and households / population
 - save / visualize
 :return:
"""

# %%
from css_geodata_service.utils import get_osm_data_weser_bergland_path, get_polygon_weser_bergland

# bounds#

polygon = get_polygon_weser_bergland()

# osm data path
osm_data_path = get_osm_data_weser_bergland_path()

# %%
# load flooded area as dataframe
affected_area = gpd.read_file(
    "~/GeoData/Flooding/HazardAreas/nz_hazardArea_fluival_H-DE_cropped_weser_bergland.geojson"
)

# %%
affected_area.head()
# Out:
#                 gml_id  beginLifeSpanVersion determinationMethod
# 0    nzHA_DETH_196_H-4                   NaN           modelling  \
# 1    nzHA_DETH_196_H-3                   NaN           modelling
# 2  nzHA_DETH_196_H-122                   NaN           modelling
# 3  nzHA_DETH_196_H-121                   NaN           modelling
# 4   nzHA_DETH_235_H-10                   NaN           modelling
#
#    endLifeSpanVersion              localId
# 0                 NaN    nzHA_DETH_196_H-4  \
# 1                 NaN    nzHA_DETH_196_H-3
# 2                 NaN  nzHA_DETH_196_H-122
# 3                 NaN  nzHA_DETH_196_H-121
# 4                 NaN   nzHA_DETH_235_H-10
#
#                                            namespace  versionId
# 0  https://registry.gdi-de.org/id/de.bund.bfg.ins...        NaN  \
# 1  https://registry.gdi-de.org/id/de.bund.bfg.ins...        NaN
# 2  https://registry.gdi-de.org/id/de.bund.bfg.ins...        NaN
# 3  https://registry.gdi-de.org/id/de.bund.bfg.ins...        NaN
# 4  https://registry.gdi-de.org/id/de.bund.bfg.ins...        NaN
#
#   qualitativeLikelihood  probabilityOfOccurrence  returnPeriod
# 0                  high                     0.05            20  \
# 1                  high                     0.05            20
# 2                  high                     0.05            20
# 3                  high                     0.05            20
# 4                  high                     0.05            20
#
#    assessmentMethod  magnitudeOrIntensity
# 0               NaN                   NaN  \
# 1               NaN                   NaN
# 2               NaN                   NaN
# 3               NaN                   NaN
# 4               NaN                   NaN
#
#                                             geometry
# 0  POLYGON ((10.05138 50.93804, 10.05139 50.93804...
# 1  POLYGON ((10.06523 50.93896, 10.06526 50.93892...
# 2  POLYGON ((10.06679 50.93976, 10.06680 50.93975...
# 3  POLYGON ((10.05677 50.94016, 10.05676 50.94016...
# 4  POLYGON ((10.08921 50.97109, 10.08921 50.97109...

# %%
from datetime import datetime

# load population data csv file
start_reading_csv_pandas = datetime.now()
population_pandas = pd.read_csv("~/GeoData/Population/population_weser_bergland.csv")
passed_reading_csv_pandas = datetime.now() - start_reading_csv_pandas
passed_reading_csv_pandas
# Out:
# datetime.timedelta(seconds=10, microseconds=951137)

# %%
population_pandas.head()
# Out:
#    person_id           cell_id  household_id  household_size
# 0          0  100mN33211E42447             0               3  \
# 1          1  100mN33211E42447             0               3
# 2          2  100mN33211E42447             0               3
# 3          3  100mN33200E42427             1               3
# 4          4  100mN33200E42427             1               3
#
#         household_type       age       sex
# 0  Paare mit Kind(ern)   50 - 64  Weiblich  \
# 1  Paare mit Kind(ern)   18 - 29  Männlich
# 2  Paare mit Kind(ern)  Unter 18  Weiblich
# 3  Paare mit Kind(ern)   18 - 29  Weiblich
# 4  Paare mit Kind(ern)   30 - 49  Männlich
#
#                                       geometry
# 0  POINT (8.864977632019484 52.99372822383581)
# 1  POINT (8.864977632019484 52.99372822383581)
# 2  POINT (8.864977632019484 52.99372822383581)
# 3         POINT (8.834359450000001 52.9834367)
# 4         POINT (8.834359450000001 52.9834367)

# %%
import shapely

population_geopandas = gpd.GeoDataFrame(
    population_pandas, geometry=population_pandas["geometry"].apply(shapely.wkt.loads)
)

# %%
population_geopandas.head()
# Out:
#    person_id           cell_id  household_id  household_size
# 0          0  100mN33211E42447             0               3  \
# 1          1  100mN33211E42447             0               3
# 2          2  100mN33211E42447             0               3
# 3          3  100mN33200E42427             1               3
# 4          4  100mN33200E42427             1               3
#
#         household_type       age       sex                  geometry
# 0  Paare mit Kind(ern)   50 - 64  Weiblich  POINT (8.86498 52.99373)
# 1  Paare mit Kind(ern)   18 - 29  Männlich  POINT (8.86498 52.99373)
# 2  Paare mit Kind(ern)  Unter 18  Weiblich  POINT (8.86498 52.99373)
# 3  Paare mit Kind(ern)   18 - 29  Weiblich  POINT (8.83436 52.98344)
# 4  Paare mit Kind(ern)   30 - 49  Männlich  POINT (8.83436 52.98344)

# %%
households = population_pandas.groupby("household_id")

# %%
households.head()
# Out:
#           person_id           cell_id  household_id  household_size
# 0                 0  100mN33211E42447             0               3  \
# 1                 1  100mN33211E42447             0               3
# 2                 2  100mN33211E42447             0               3
# 3                 3  100mN33200E42427             1               3
# 4                 4  100mN33200E42427             1               3
# ...             ...               ...           ...             ...
# 12627617   12627617  100mN32134E42214       6098875               2
# 12627618   12627618  100mN32134E42214       6098875               2
# 12627619   12627619  100mN32134E42214       6098876               1
# 12627620   12627620  100mN32134E42214       6098877               1
# 12627621   12627621  100mN32134E42214       6098878               1
#
#                                   household_type       age       sex
# 0                            Paare mit Kind(ern)   50 - 64  Weiblich  \
# 1                            Paare mit Kind(ern)   18 - 29  Männlich
# 2                            Paare mit Kind(ern)  Unter 18  Weiblich
# 3                            Paare mit Kind(ern)   18 - 29  Weiblich
# 4                            Paare mit Kind(ern)   30 - 49  Männlich
# ...                                          ...       ...       ...
# 12627617                     Paare ohne Kind(er)   18 - 29  Weiblich
# 12627618                     Paare ohne Kind(er)   30 - 49  Männlich
# 12627619  Einpersonenhaushalte (Singlehaushalte)   30 - 49  Weiblich
# 12627620  Einpersonenhaushalte (Singlehaushalte)   30 - 49  Weiblich
# 12627621  Einpersonenhaushalte (Singlehaushalte)   30 - 49  Weiblich
#
#                                               location
# 0          POINT (8.864977632019484 52.99372822383581)
# 1          POINT (8.864977632019484 52.99372822383581)
# 2          POINT (8.864977632019484 52.99372822383581)
# 3                 POINT (8.834359450000001 52.9834367)
# 4                 POINT (8.834359450000001 52.9834367)
# ...                                                ...
# 12627617  POINT (8.549510265037483 52.022315405216844)
# 12627618  POINT (8.549510265037483 52.022315405216844)
# 12627619  POINT (8.549510265037483 52.022315405216844)
# 12627620  POINT (8.549510265037483 52.022315405216844)
# 12627621  POINT (8.549510265037483 52.022315405216844)
#
# [12584745 rows x 8 columns]

# %%
from css_geodata_service.extract.system_tools import extract_buildings_from_pbf_to_osmxml

# get bounds from osm data or set manually
# extract buildings from osm data using extract_buildings_from_pbf_to_osmxml
buildings_path = "~/GeoData/OSM/Buildings/buildings_weser_bergland.osm"

# %%
result = extract_buildings_from_pbf_to_osmxml(osm_data_path, output_file_path=buildings_path)
# load buildings using geopandas

# %%
result
# Out:
# CompletedProcess(args='osmium tags-filter /Users/kaub/GeoData/OSM/weser_bergland.osm_osmium.pbf w/building= -o ~/GeoData/OSM/Buildings/buildings_weser_bergland.osm --overwrite', returncode=0, stdout=b'', stderr=b'')

# %%
from pathlib import Path
import os

# %%
abs_building_path = os.path.expanduser(buildings_path)
abs_building_path
# Out:
# '/Users/kaub/GeoData/OSM/Buildings/buildings_weser_bergland.osm'

# %%
# get current working directory
cwd = Path.cwd()
cwd
# Out:
# PosixPath('/Users/kaub/PycharmProjects/css-geodata-service/css_geodata_service/affected_persons')

# %%
# Path to the osmconf.ini file
osm_conf_path = "osmconf.ini"  # Replace with the actual path to osmconf.ini

# Set the OSM_CONFIG_FILE environment variable
os.environ["OSM_CONFIG_FILE"] = osm_conf_path

# %%
test = gpd.read_file("~/Downloads/map.osm", driver="OSM")
# Out:
# ---------------------------------------------------------------------------
# DriverError                               Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 test = gpd.read_file("~/Downloads/map.osm", driver="OSM")
#
# File ~/PycharmProjects/css-geodata-service/.venv/lib/python3.11/site-packages/geopandas/io/file.py:248, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     245     else:
#     246         path_or_bytes = filename
# --> 248     return _read_file_fiona(
#     249         path_or_bytes, from_bytes, bbox=bbox, mask=mask, rows=rows, **kwargs
#     250     )
#     252 else:
#     253     raise ValueError(f"unknown engine '{engine}'")
#
# File ~/PycharmProjects/css-geodata-service/.venv/lib/python3.11/site-packages/geopandas/io/file.py:289, in _read_file_fiona(path_or_bytes, from_bytes, bbox, mask, rows, where, **kwargs)
#     286     reader = fiona.open
#     288 with fiona_env():
# --> 289     with reader(path_or_bytes, **kwargs) as features:
#     290         crs = features.crs_wkt
#     291         # attempt to get EPSG code
#
# File ~/PycharmProjects/css-geodata-service/.venv/lib/python3.11/site-packages/fiona/env.py:457, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     454     session = DummySession()
#     456 with env_ctor(session=session):
# --> 457     return f(*args, **kwds)
#
# File ~/PycharmProjects/css-geodata-service/.venv/lib/python3.11/site-packages/fiona/__init__.py:336, in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, allow_unsupported_drivers, **kwargs)
#     333     path = parse_path(fp)
#     335 if mode in ("a", "r"):
# --> 336     colxn = Collection(
#     337         path,
#     338         mode,
#     339         driver=driver,
#     340         encoding=encoding,
#     341         layer=layer,
#     342         enabled_drivers=enabled_drivers,
#     343         allow_unsupported_drivers=allow_unsupported_drivers,
#     344         **kwargs
#     345     )
#     346 elif mode == "w":
#     347     colxn = Collection(
#     348         path,
#     349         mode,
#    (...)
#     358         **kwargs
#     359     )
#
# File ~/PycharmProjects/css-geodata-service/.venv/lib/python3.11/site-packages/fiona/collection.py:252, in Collection.__init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, include_fields, wkt_version, allow_unsupported_drivers, **kwargs)
#     249     raise
#     251 if self.session is not None:
# --> 252     self.guard_driver_mode()
#     254 if self.mode in ("a", "w"):
#     255     self._valid_geom_types = _get_valid_geom_types(self.schema, self.driver)
#
# File ~/PycharmProjects/css-geodata-service/.venv/lib/python3.11/site-packages/fiona/collection.py:273, in Collection.guard_driver_mode(self)
#     271 driver = self.session.get_driver()
#     272 if driver not in supported_drivers:
# --> 273     raise DriverError("unsupported driver: %r" % driver)
#     274 if self.mode not in supported_drivers[driver]:
#     275     raise DriverError("unsupported mode: %r" % self.mode)
#
# DriverError: unsupported driver: 'OSM'

# %%
# todo apparently this does not work - ignore for now and load preexisting buildings
all_buildings = gpd.read_file("~/GeoData/OSM/Buildings/all_buildings_weser_bergland.osm", driver="OSM")
# Out:
# ---------------------------------------------------------------------------
# DriverError                               Traceback (most recent call last)
# Cell In[88], line 2
#       1 # todo apparently this does not work - ignore for now and load preexisting buildings
# ----> 2 all_buildings = gpd.read_file("~/GeoData/OSM/Buildings/all_buildings_weser_bergland.osm", driver="OSM")
#
# File ~/PycharmProjects/css-geodata-service/.venv/lib/python3.11/site-packages/geopandas/io/file.py:248, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     245     else:
#     246         path_or_bytes = filename
# --> 248     return _read_file_fiona(
#     249         path_or_bytes, from_bytes, bbox=bbox, mask=mask, rows=rows, **kwargs
#     250     )
#     252 else:
#     253     raise ValueError(f"unknown engine '{engine}'")
#
# File ~/PycharmProjects/css-geodata-service/.venv/lib/python3.11/site-packages/geopandas/io/file.py:289, in _read_file_fiona(path_or_bytes, from_bytes, bbox, mask, rows, where, **kwargs)
#     286     reader = fiona.open
#     288 with fiona_env():
# --> 289     with reader(path_or_bytes, **kwargs) as features:
#     290         crs = features.crs_wkt
#     291         # attempt to get EPSG code
#
# File ~/PycharmProjects/css-geodata-service/.venv/lib/python3.11/site-packages/fiona/env.py:457, in ensure_env_with_credentials.<locals>.wrapper(*args, **kwds)
#     454     session = DummySession()
#     456 with env_ctor(session=session):
# --> 457     return f(*args, **kwds)
#
# File ~/PycharmProjects/css-geodata-service/.venv/lib/python3.11/site-packages/fiona/__init__.py:336, in open(fp, mode, driver, schema, crs, encoding, layer, vfs, enabled_drivers, crs_wkt, allow_unsupported_drivers, **kwargs)
#     333     path = parse_path(fp)
#     335 if mode in ("a", "r"):
# --> 336     colxn = Collection(
#     337         path,
#     338         mode,
#     339         driver=driver,
#     340         encoding=encoding,
#     341         layer=layer,
#     342         enabled_drivers=enabled_drivers,
#     343         allow_unsupported_drivers=allow_unsupported_drivers,
#     344         **kwargs
#     345     )
#     346 elif mode == "w":
#     347     colxn = Collection(
#     348         path,
#     349         mode,
#    (...)
#     358         **kwargs
#     359     )
#
# File ~/PycharmProjects/css-geodata-service/.venv/lib/python3.11/site-packages/fiona/collection.py:252, in Collection.__init__(self, path, mode, driver, schema, crs, encoding, layer, vsi, archive, enabled_drivers, crs_wkt, ignore_fields, ignore_geometry, include_fields, wkt_version, allow_unsupported_drivers, **kwargs)
#     249     raise
#     251 if self.session is not None:
# --> 252     self.guard_driver_mode()
#     254 if self.mode in ("a", "w"):
#     255     self._valid_geom_types = _get_valid_geom_types(self.schema, self.driver)
#
# File ~/PycharmProjects/css-geodata-service/.venv/lib/python3.11/site-packages/fiona/collection.py:273, in Collection.guard_driver_mode(self)
#     271 driver = self.session.get_driver()
#     272 if driver not in supported_drivers:
# --> 273     raise DriverError("unsupported driver: %r" % driver)
#     274 if self.mode not in supported_drivers[driver]:
#     275     raise DriverError("unsupported mode: %r" % self.mode)
#
# DriverError: unsupported driver: 'OSM'

# %%
buildings = gpd.read_file("~/GeoData/OSM/residential_weser_bergland.gpkg")

# %%
buildings.head()
# Out:
#   addr:city addr:country addr:housenumber addr:housename addr:postcode
# 0  Herdecke           DE                9            NaN         58313  \
# 1  Herdecke           DE                3            NaN         58313
# 2  Herdecke           DE               15            NaN         58313
# 3  Herdecke           DE               16            NaN         58313
# 4  Herdecke           DE               18            NaN         58313
#
#   addr:place    addr:street email name opening_hours  ... source start_date
# 0        NaN  Harkortstraße   NaN  NaN           NaN  ...    NaN        NaN  \
# 1        NaN    Rilkestraße   NaN  NaN           NaN  ...    NaN        NaN
# 2        NaN    Rilkestraße   NaN  NaN           NaN  ...    NaN        NaN
# 3        NaN  Harkortstraße   NaN  NaN           NaN  ...    NaN        NaN
# 4        NaN  Harkortstraße   NaN  NaN           NaN  ...    NaN        NaN
#
#   wikipedia        id timestamp version tags osm_type changeset
# 0       NaN  21602313         0      -1  NaN      way       NaN  \
# 1       NaN  21602560         0      -1  NaN      way       NaN
# 2       NaN  21602812         0      -1  NaN      way       NaN
# 3       NaN  21602892         0      -1  NaN      way       NaN
# 4       NaN  21602965         0      -1  NaN      way       NaN
#
#                                             geometry
# 0  POLYGON ((7.42731 51.40072, 7.42715 51.40078, ...
# 1  POLYGON ((7.42802 51.40119, 7.42808 51.40133, ...
# 2  POLYGON ((7.42668 51.40140, 7.42675 51.40152, ...
# 3  POLYGON ((7.42705 51.40108, 7.42712 51.40118, ...
# 4  POLYGON ((7.42688 51.40125, 7.42682 51.40116, ...
#
# [5 rows x 38 columns]

# %%
# reproject affected area to buildings crs
# affected_area = affected_area.to_crs(buildings.crs)

# %%
population_geopandas = population_geopandas.to_crs(affected_area.crs)

# %%
affected_buildings = gpd.sjoin(buildings, affected_area, how="inner", op="intersects")
# Out:
# /Users/kaub/PycharmProjects/css-geodata-service/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):

# %%
affected_buildings.head()
# Out:
#        addr:city addr:country addr:housenumber addr:housename addr:postcode
# 92         Lügde           DE                2            NaN         32676  \
# 93         Lügde           DE                4            NaN         32676
# 94         Lügde           DE                8            NaN         32676
# 95         Lügde           DE              8 a            NaN         32676
# 96         Lügde           DE               10            NaN         32676
# ...          ...          ...              ...            ...           ...
# 219809  Meinhard           DE               15            NaN         37276
# 219810  Meinhard           DE               10            NaN         37276
# 220540  Meinhard           DE               2a            NaN         37276
# 222140  Eschwege           DE                2            NaN         37269
# 223051  Liebenau          NaN               25            NaN         31618
#
#        addr:place        addr:street email name opening_hours  ...
# 92            NaN       Höxterstraße   NaN  NaN           NaN  ...  \
# 93            NaN       Höxterstraße   NaN  NaN           NaN  ...
# 94            NaN       Höxterstraße   NaN  NaN           NaN  ...
# 95            NaN       Höxterstraße   NaN  NaN           NaN  ...
# 96            NaN       Höxterstraße   NaN  NaN           NaN  ...
# ...           ...                ...   ...  ...           ...  ...
# 219809        NaN   Eschweger Straße   NaN  NaN           NaN  ...
# 219810        NaN  Schwebdaer Straße   NaN  NaN           NaN  ...
# 220540        NaN   Eschweger Straße   NaN  NaN           NaN  ...
# 222140        NaN       An der Berka   NaN  NaN           NaN  ...
# 223051        NaN       Lange Straße   NaN  NaN           NaN  ...
#
#           determinationMethod endLifeSpanVersion              localId
# 92      indirectDetermination                NaN  nzHA_DENW_4_240_H-4  \
# 93      indirectDetermination                NaN  nzHA_DENW_4_240_H-4
# 94      indirectDetermination                NaN  nzHA_DENW_4_240_H-4
# 95      indirectDetermination                NaN  nzHA_DENW_4_240_H-4
# 96      indirectDetermination                NaN  nzHA_DENW_4_240_H-4
# ...                       ...                ...                  ...
# 219809  indirectDetermination                NaN   nzHA_DEHE_3995_H-1
# 219810  indirectDetermination                NaN   nzHA_DEHE_3995_H-1
# 220540  indirectDetermination                NaN   nzHA_DEHE_3998_H-1
# 222140  indirectDetermination                NaN   nzHA_DEHE_4002_H-1
# 223051  indirectDetermination                NaN   nzHA_DENI20847_H-1
#
#                                                 namespace versionId
# 92      https://registry.gdi-de.org/id/de.bund.bfg.ins...       NaN  \
# 93      https://registry.gdi-de.org/id/de.bund.bfg.ins...       NaN
# 94      https://registry.gdi-de.org/id/de.bund.bfg.ins...       NaN
# 95      https://registry.gdi-de.org/id/de.bund.bfg.ins...       NaN
# 96      https://registry.gdi-de.org/id/de.bund.bfg.ins...       NaN
# ...                                                   ...       ...
# 219809  https://registry.gdi-de.org/id/de.bund.bfg.ins...       NaN
# 219810  https://registry.gdi-de.org/id/de.bund.bfg.ins...       NaN
# 220540  https://registry.gdi-de.org/id/de.bund.bfg.ins...       NaN
# 222140  https://registry.gdi-de.org/id/de.bund.bfg.ins...       NaN
# 223051  https://registry.gdi-de.org/id/de.bund.bfg.ins...       NaN
#
#        qualitativeLikelihood probabilityOfOccurrence returnPeriod
# 92                      high                    0.05           20  \
# 93                      high                    0.05           20
# 94                      high                    0.05           20
# 95                      high                    0.05           20
# 96                      high                    0.05           20
# ...                      ...                     ...          ...
# 219809                  high                    0.05           20
# 219810                  high                    0.05           20
# 220540                  high                    0.05           20
# 222140                  high                    0.05           20
# 223051                  high                    0.05           20
#
#        assessmentMethod magnitudeOrIntensity
# 92                  NaN                  NaN
# 93                  NaN                  NaN
# 94                  NaN                  NaN
# 95                  NaN                  NaN
# 96                  NaN                  NaN
# ...                 ...                  ...
# 219809              NaN                  NaN
# 219810              NaN                  NaN
# 220540              NaN                  NaN
# 222140              NaN                  NaN
# 223051              NaN                  NaN
#
# [1380 rows x 51 columns]
#    addr:city addr:country addr:housenumber addr:housename addr:postcode
# 92     Lügde           DE                2            NaN         32676  \
# 93     Lügde           DE                4            NaN         32676
# 94     Lügde           DE                8            NaN         32676
# 95     Lügde           DE              8 a            NaN         32676
# 96     Lügde           DE               10            NaN         32676
#
#    addr:place   addr:street email name opening_hours  ...
# 92        NaN  Höxterstraße   NaN  NaN           NaN  ...  \
# 93        NaN  Höxterstraße   NaN  NaN           NaN  ...
# 94        NaN  Höxterstraße   NaN  NaN           NaN  ...
# 95        NaN  Höxterstraße   NaN  NaN           NaN  ...
# 96        NaN  Höxterstraße   NaN  NaN           NaN  ...
#
#       determinationMethod endLifeSpanVersion              localId
# 92  indirectDetermination                NaN  nzHA_DENW_4_240_H-4  \
# 93  indirectDetermination                NaN  nzHA_DENW_4_240_H-4
# 94  indirectDetermination                NaN  nzHA_DENW_4_240_H-4
# 95  indirectDetermination                NaN  nzHA_DENW_4_240_H-4
# 96  indirectDetermination                NaN  nzHA_DENW_4_240_H-4
#
#                                             namespace versionId
# 92  https://registry.gdi-de.org/id/de.bund.bfg.ins...       NaN  \
# 93  https://registry.gdi-de.org/id/de.bund.bfg.ins...       NaN
# 94  https://registry.gdi-de.org/id/de.bund.bfg.ins...       NaN
# 95  https://registry.gdi-de.org/id/de.bund.bfg.ins...       NaN
# 96  https://registry.gdi-de.org/id/de.bund.bfg.ins...       NaN
#
#    qualitativeLikelihood probabilityOfOccurrence returnPeriod
# 92                  high                    0.05           20  \
# 93                  high                    0.05           20
# 94                  high                    0.05           20
# 95                  high                    0.05           20
# 96                  high                    0.05           20
#
#    assessmentMethod magnitudeOrIntensity
# 92              NaN                  NaN
# 93              NaN                  NaN
# 94              NaN                  NaN
# 95              NaN                  NaN
# 96              NaN                  NaN
#
# [5 rows x 51 columns]

# %%
len(affected_buildings)
# Out:
# 1380

# %%
# ignore buildings just look at households and persons
affected_population = gpd.sjoin(population_geopandas, affected_area, how="inner", op="intersects")
# Out:
# /Users/kaub/PycharmProjects/css-geodata-service/.venv/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3448: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if await self.run_code(code, result, async_=asy):
# /var/folders/ft/kkbmdx9s4fb0x94nztz0spp00000gn/T/ipykernel_47640/864890825.py:2: UserWarning: CRS mismatch between the CRS of left geometries and the CRS of right geometries.
# Use `to_crs()` to reproject one of the input geometries to match the CRS of the other.
#
# Left CRS: None
# Right CRS: EPSG:4326
#
#   affected_population = gpd.sjoin(population_geopandas, affected_area, how="inner", op="intersects")

# %%
affected_population.head()
# Out:
#        person_id           cell_id  household_id  household_size
# 10196      10196  100mN31058E42361          4949               3  \
# 10197      10197  100mN31058E42361          4949               3
# 10198      10198  100mN31058E42361          4949               3
# 10199      10199  100mN31058E42361          4950               4
# 10200      10200  100mN31058E42361          4950               4
#
#             household_type       age       sex                  geometry
# 10196  Paare mit Kind(ern)   18 - 29  Weiblich  POINT (8.79043 51.05779)  \
# 10197  Paare mit Kind(ern)   18 - 29  Männlich  POINT (8.79043 51.05779)
# 10198  Paare mit Kind(ern)  Unter 18  Männlich  POINT (8.79043 51.05779)
# 10199  Paare mit Kind(ern)   18 - 29  Weiblich  POINT (8.79043 51.05779)
# 10200  Paare mit Kind(ern)   30 - 49  Männlich  POINT (8.79043 51.05779)
#
#        index_right              gml_id  ...    determinationMethod
# 10196         2669  nzHA_DEHE_2194_H-1  ...  indirectDetermination  \
# 10197         2669  nzHA_DEHE_2194_H-1  ...  indirectDetermination
# 10198         2669  nzHA_DEHE_2194_H-1  ...  indirectDetermination
# 10199         2669  nzHA_DEHE_2194_H-1  ...  indirectDetermination
# 10200         2669  nzHA_DEHE_2194_H-1  ...  indirectDetermination
#
#       endLifeSpanVersion             localId
# 10196                NaN  nzHA_DEHE_2194_H-1  \
# 10197                NaN  nzHA_DEHE_2194_H-1
# 10198                NaN  nzHA_DEHE_2194_H-1
# 10199                NaN  nzHA_DEHE_2194_H-1
# 10200                NaN  nzHA_DEHE_2194_H-1
#
#                                                namespace versionId
# 10196  https://registry.gdi-de.org/id/de.bund.bfg.ins...       NaN  \
# 10197  https://registry.gdi-de.org/id/de.bund.bfg.ins...       NaN
# 10198  https://registry.gdi-de.org/id/de.bund.bfg.ins...       NaN
# 10199  https://registry.gdi-de.org/id/de.bund.bfg.ins...       NaN
# 10200  https://registry.gdi-de.org/id/de.bund.bfg.ins...       NaN
#
#        qualitativeLikelihood probabilityOfOccurrence  returnPeriod
# 10196                   high                     0.1            10  \
# 10197                   high                     0.1            10
# 10198                   high                     0.1            10
# 10199                   high                     0.1            10
# 10200                   high                     0.1            10
#
#        assessmentMethod  magnitudeOrIntensity
# 10196               NaN                   NaN
# 10197               NaN                   NaN
# 10198               NaN                   NaN
# 10199               NaN                   NaN
# 10200               NaN                   NaN
#
# [5 rows x 21 columns]

# %%
len(affected_population)
# Out:
# 47359

# %%
population_geopandas.head()
# Out:
#    person_id           cell_id  household_id  household_size
# 0          0  100mN33211E42447             0               3  \
# 1          1  100mN33211E42447             0               3
# 2          2  100mN33211E42447             0               3
# 3          3  100mN33200E42427             1               3
# 4          4  100mN33200E42427             1               3
#
#         household_type       age       sex                  geometry
# 0  Paare mit Kind(ern)   50 - 64  Weiblich  POINT (8.86498 52.99373)
# 1  Paare mit Kind(ern)   18 - 29  Männlich  POINT (8.86498 52.99373)
# 2  Paare mit Kind(ern)  Unter 18  Weiblich  POINT (8.86498 52.99373)
# 3  Paare mit Kind(ern)   18 - 29  Weiblich  POINT (8.83436 52.98344)
# 4  Paare mit Kind(ern)   30 - 49  Männlich  POINT (8.83436 52.98344)

# %%
population_geopandas_relevant_data = population_geopandas[["cell_id", "geometry"]]
population_geopandas_relevant_data.head()
# Out:
#             cell_id                  geometry
# 0  100mN33211E42447  POINT (8.86498 52.99373)
# 1  100mN33211E42447  POINT (8.86498 52.99373)
# 2  100mN33211E42447  POINT (8.86498 52.99373)
# 3  100mN33200E42427  POINT (8.83436 52.98344)
# 4  100mN33200E42427  POINT (8.83436 52.98344)

# %%
# to increase speed first use only the unique locations / buildings and then filter the population
unique_locations_in_population = population_geopandas_relevant_data.drop_duplicates(subset=["geometry"])

# %%
unique_locations_in_population.head()
# Out:
#              cell_id                  geometry
# 0   100mN33211E42447  POINT (8.86498 52.99373)
# 3   100mN33200E42427  POINT (8.83436 52.98344)
# 6   100mN33200E42427  POINT (8.83459 52.98368)
# 8   100mN33200E42427  POINT (8.83419 52.98364)
# 11  100mN33200E42427  POINT (8.83564 52.98344)

# %%
len(population_geopandas)
# Out:
# 12627622

# %%
len(unique_locations_in_population)
# Out:
# 2641628

# %%
import logging

logging.basicConfig(level=logging.INFO)

# %%
logger = logging.getLogger(__name__)

# %%
from css_geodata_service.extract.python_tools import filter_gdf_from_from_gdf_filter_own

# try this using utils
filtered_population = filter_gdf_from_from_gdf_filter_own(unique_locations_in_population, affected_area)
# Out:
# INFO:css_geodata_service.extract.python_tools:Starting to filter data from polygons
# INFO:css_geodata_service.extract.python_tools:Processing polygons 0.00% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 0.98% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 1.97% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 2.95% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 3.94% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 4.92% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 5.90% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 6.89% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 7.87% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 8.86% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 9.84% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 10.83% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 11.81% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 12.79% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 13.78% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 14.76% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 15.75% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 16.73% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 17.71% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 18.70% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 19.68% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 20.67% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 21.65% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 22.64% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 23.62% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 24.60% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 25.59% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 26.57% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 27.56% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 28.54% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 29.52% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 30.51% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 31.49% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 32.48% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 33.46% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 34.45% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 35.43% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 36.41% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 37.40% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 38.38% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 39.37% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 40.35% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 41.33% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 42.32% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 43.30% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 44.29% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 45.27% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 46.26% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 47.24% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 48.22% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 49.21% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 50.19% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 51.18% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 52.16% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 53.14% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 54.13% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 55.11% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 56.10% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 57.08% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 58.07% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 59.05% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 60.03% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 61.02% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 62.00% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 62.99% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 63.97% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 64.95% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 65.94% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 66.92% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 67.91% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 68.89% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 69.88% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 70.86% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 71.84% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 72.83% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 73.81% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 74.80% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 75.78% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 76.76% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 77.75% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 78.73% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 79.72% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 80.70% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 81.68% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 82.67% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 83.65% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 84.64% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 85.62% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 86.61% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 87.59% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 88.57% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 89.56% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 90.54% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 91.53% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 92.51% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 93.49% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 94.48% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 95.46% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 96.45% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 97.43% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 98.42% complete
# INFO:css_geodata_service.extract.python_tools:Processing polygons 99.40% complete

# %%
filtered_population.head()
# Out:
#                   cell_id                  geometry
# 8552456  100mN31907E42283  POINT (8.65678 51.81948)
# 8552465  100mN31907E42283  POINT (8.65648 51.81974)
# 9371671  100mN31547E41717  POINT (7.85148 51.48413)
# 8552473  100mN31907E42283  POINT (8.65571 51.81888)
# 9371674  100mN31547E41717  POINT (7.85069 51.48408)

# %%
len(filtered_population)  # das sind 9783 unique locations -> gebäude. Entscheprechend mehr Haushalte und Personen
# Out:
# 9783

# %%
from shapely import Point

# todo from the points get the households and persons
# test if point objects can be compared
p1 = Point(0, 0)
p2 = Point(0, 0)
p1 == p2
# Out:
# True

# %%
mask = population_geopandas["geometry"].isin(filtered_population["geometry"])

# %%
len(mask)
# Out:
# 12627622

# %%
affected_population_v2 = population_geopandas[mask]

# %%
len(affected_population_v2)
# Out:
# 47129

# %%
len(affected_population)
# Out:
# 47359

# %%
affected_population.head()
# Out:
#        person_id           cell_id  household_id  household_size
# 10196      10196  100mN31058E42361          4949               3  \
# 10197      10197  100mN31058E42361          4949               3
# 10198      10198  100mN31058E42361          4949               3
# 10199      10199  100mN31058E42361          4950               4
# 10200      10200  100mN31058E42361          4950               4
#
#             household_type       age       sex                  geometry
# 10196  Paare mit Kind(ern)   18 - 29  Weiblich  POINT (8.79043 51.05779)  \
# 10197  Paare mit Kind(ern)   18 - 29  Männlich  POINT (8.79043 51.05779)
# 10198  Paare mit Kind(ern)  Unter 18  Männlich  POINT (8.79043 51.05779)
# 10199  Paare mit Kind(ern)   18 - 29  Weiblich  POINT (8.79043 51.05779)
# 10200  Paare mit Kind(ern)   30 - 49  Männlich  POINT (8.79043 51.05779)
#
#        index_right              gml_id  ...    determinationMethod
# 10196         2669  nzHA_DEHE_2194_H-1  ...  indirectDetermination  \
# 10197         2669  nzHA_DEHE_2194_H-1  ...  indirectDetermination
# 10198         2669  nzHA_DEHE_2194_H-1  ...  indirectDetermination
# 10199         2669  nzHA_DEHE_2194_H-1  ...  indirectDetermination
# 10200         2669  nzHA_DEHE_2194_H-1  ...  indirectDetermination
#
#       endLifeSpanVersion             localId
# 10196                NaN  nzHA_DEHE_2194_H-1  \
# 10197                NaN  nzHA_DEHE_2194_H-1
# 10198                NaN  nzHA_DEHE_2194_H-1
# 10199                NaN  nzHA_DEHE_2194_H-1
# 10200                NaN  nzHA_DEHE_2194_H-1
#
#                                                namespace versionId
# 10196  https://registry.gdi-de.org/id/de.bund.bfg.ins...       NaN  \
# 10197  https://registry.gdi-de.org/id/de.bund.bfg.ins...       NaN
# 10198  https://registry.gdi-de.org/id/de.bund.bfg.ins...       NaN
# 10199  https://registry.gdi-de.org/id/de.bund.bfg.ins...       NaN
# 10200  https://registry.gdi-de.org/id/de.bund.bfg.ins...       NaN
#
#        qualitativeLikelihood probabilityOfOccurrence  returnPeriod
# 10196                   high                     0.1            10  \
# 10197                   high                     0.1            10
# 10198                   high                     0.1            10
# 10199                   high                     0.1            10
# 10200                   high                     0.1            10
#
#        assessmentMethod  magnitudeOrIntensity
# 10196               NaN                   NaN
# 10197               NaN                   NaN
# 10198               NaN                   NaN
# 10199               NaN                   NaN
# 10200               NaN                   NaN
#
# [5 rows x 21 columns]

# %%
affected_population.describe()
# Out:
#           person_id  household_id  household_size   index_right
# count  4.735900e+04  4.735900e+04     47359.00000  47359.000000  \
# mean   6.426918e+06  3.104202e+06         2.68403   3846.317595
# std    3.725957e+06  1.799612e+06         1.24104   2869.276138
# min    1.019600e+04  4.949000e+03         1.00000      2.000000
# 25%    3.019790e+06  1.458727e+06         2.00000   1729.000000
# 50%    6.429374e+06  3.105265e+06         2.00000   2488.000000
# 75%    9.761204e+06  4.714632e+06         4.00000   6069.000000
# max    1.262125e+07  6.095858e+06         6.00000  10153.000000
#
#        beginLifeSpanVersion  endLifeSpanVersion  versionId
# count                   0.0                 0.0        0.0  \
# mean                    NaN                 NaN        NaN
# std                     NaN                 NaN        NaN
# min                     NaN                 NaN        NaN
# 25%                     NaN                 NaN        NaN
# 50%                     NaN                 NaN        NaN
# 75%                     NaN                 NaN        NaN
# max                     NaN                 NaN        NaN
#
#        probabilityOfOccurrence  returnPeriod  assessmentMethod
# count             47359.000000  47359.000000               0.0  \
# mean                  0.058913     19.170907               NaN
# std                   0.021128      9.388894               NaN
# min                   0.010000      5.000000               NaN
# 25%                   0.050000     20.000000               NaN
# 50%                   0.050000     20.000000               NaN
# 75%                   0.050000     20.000000               NaN
# max                   0.200000    100.000000               NaN
#
#        magnitudeOrIntensity
# count                   0.0
# mean                    NaN
# std                     NaN
# min                     NaN
# 25%                     NaN
# 50%                     NaN
# 75%                     NaN
# max                     NaN

# %%
in_a_but_not_in_b = affected_population[~affected_population.index.isin(affected_population_v2.index)]
in_b_but_not_in_a = affected_population_v2[~affected_population_v2.index.isin(affected_population.index)]

# %%
affected_population.plot()
# Out:
# <Axes: >
